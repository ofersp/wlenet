# %%
import numpy as np
from os.path import expanduser
from wlenet import config
from wlenet.models.utils import load_spec, print_spec
from wlenet.models.batch import train_a_spec
# Out:
# /cs/phd/springer/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
"""
model_spec = {'arch_name': 'cnn_image',
              'kwargs_arch': {'dropout_dense_rate': 0.3, 'out_dim': 2, 'use_discriminator': False, 'use_dropout_dense': True},
              'kwargs_dataset': {'noise_kernel_factor': 1.0,
                                 'noise_kernel_name': 'clash',
                                 'sim_names_test': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'sim_names_train': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'target_header_path': None},
              'kwargs_train': {'epochs': 100, 'label_loss': 'mean_squared_error', 'patience': 10},
              'trained_name': 'cnn_image_clash_uniform_mse'}

post_sim_path = config['calibration_path'] + '/cosmos_to_clash_post_sim.npy'
model_spec['kwargs_dataset']['post_sim'] = np.load(expanduser(post_sim_path)).item()
model_spec['kwargs_dataset']['post_sim']['flux_factor'] = 0.32

train_a_spec(model_spec, do_train=True, save_calib=True, show_figures=True)"""
pass

# %%
model_spec = {'arch_name': 'cnn_image',
              'kwargs_arch': {'dropout_dense_rate': 0.3, 'out_dim': 2, 'use_discriminator': False, 'use_dropout_dense': True},
              'kwargs_dataset': {'noise_kernel_factor': 0.250,
                                 'noise_kernel_name': 'clash',
                                 'sim_names_test': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'sim_names_train': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'target_header_path': None},
              'kwargs_train': {'epochs': 100, 'label_loss': 'mean_squared_error', 'patience': 10},
              'trained_name': 'cnn_image_clash_uniform_mse_noise_0.250'}

post_sim_path = config['calibration_path'] + '/cosmos_to_clash_post_sim.npy'
model_spec['kwargs_dataset']['post_sim'] = np.load(expanduser(post_sim_path)).item()
model_spec['kwargs_dataset']['post_sim']['flux_factor'] = 0.32

train_a_spec(model_spec, do_train=True, save_calib=True, show_figures=True)
# Out:
# {'arch_name': 'cnn_image',
#  'kwargs_arch': {'dropout_dense_rate': 0.3, 'out_dim': 2, 'use_discriminator': False, 'use_dropout_dense': True},
#  'kwargs_dataset': {'noise_kernel_factor': 0.25,
#                     'noise_kernel_name': 'clash',
#                     'post_sim': {'flux_cut_min': -inf, 'flux_factor': 0.32, 'intensity_cutoff': 0.012},
#                     'sim_names_test': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
#                     'sim_names_train': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
#                     'target_header_path': None},
#  'kwargs_train': {'epochs': 100, 'label_loss': 'mean_squared_error', 'patience': 10},
#  'trained_name': 'cnn_image_clash_uniform_mse_noise_0.250'}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 10, 10, 64)        1664
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 10, 10, 40)        2600
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 10, 10, 10)        410
# _________________________________________________________________
# flatten (Flatten)            (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               100100
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                3030
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# label_pred (Dense)           (None, 2)                 62
# =================================================================
# Total params: 107,866
# Trainable params: 107,866
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  - 25s - loss: 0.0108 - val_loss: 0.0101
# Epoch 2/100
#  - 23s - loss: 0.0104 - val_loss: 0.0099
# Epoch 3/100
#  - 24s - loss: 0.0103 - val_loss: 0.0098
# Epoch 4/100
#  - 24s - loss: 0.0102 - val_loss: 0.0098
# Epoch 5/100
#  - 24s - loss: 0.0102 - val_loss: 0.0098
# Epoch 6/100
#  - 24s - loss: 0.0102 - val_loss: 0.0098
# Epoch 7/100
#  - 24s - loss: 0.0102 - val_loss: 0.0099
# Epoch 8/100
#  - 24s - loss: 0.0101 - val_loss: 0.0097
# Epoch 9/100
#  - 24s - loss: 0.0101 - val_loss: 0.0097
# Epoch 10/100
#  - 24s - loss: 0.0101 - val_loss: 0.0097
# Epoch 11/100
#  - 25s - loss: 0.0101 - val_loss: 0.0097
# Epoch 12/100
#  - 24s - loss: 0.0101 - val_loss: 0.0097
# Epoch 13/100
#  - 24s - loss: 0.0101 - val_loss: 0.0097
# Epoch 14/100
#  - 24s - loss: 0.0101 - val_loss: 0.0098
# Epoch 15/100
#  - 23s - loss: 0.0101 - val_loss: 0.0097
# Epoch 16/100
#  - 24s - loss: 0.0100 - val_loss: 0.0097
# Epoch 17/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 18/100
#  - 24s - loss: 0.0100 - val_loss: 0.0097
# Epoch 19/100
#  - 24s - loss: 0.0100 - val_loss: 0.0097
# Epoch 20/100
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 21/100
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 22/100
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 23/100
#
# Epoch 00023: reducing learning rate to 9.486833431105525e-05.
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 24/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 25/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 26/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 27/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 28/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 29/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 30/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 31/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 32/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 33/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 34/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 35/100
#
# Epoch 00035: reducing learning rate to 3.0000002378990563e-05.
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 36/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 37/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 38/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 39/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 40/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 41/100
#  - 25s - loss: 0.0098 - val_loss: 0.0095
# Epoch 42/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 43/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 44/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 45/100
#
# Epoch 00045: reducing learning rate to 9.48683389127749e-06.
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 46/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 47/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 48/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 49/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 50/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 51/100
#  - 24s - loss: 0.0099 - val_loss: 0.0095
# Epoch 52/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 53/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 54/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 55/100
#
# Epoch 00055: reducing learning rate to 3.0000002378990564e-06.
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 56/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 57/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 58/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 59/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 60/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 61/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 62/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 63/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 64/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 65/100
#
# Epoch 00065: reducing learning rate to 2e-06.
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 66/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 67/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 68/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 69/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 70/100
#  - 23s - loss: 0.0099 - val_loss: 0.0095
# Epoch 71/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 72/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 73/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 74/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 75/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 76/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 77/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 78/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 79/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 80/100
#  - 25s - loss: 0.0098 - val_loss: 0.0095
# Epoch 81/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 82/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 83/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 84/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 85/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 86/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 87/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 88/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 89/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 90/100
#  - 23s - loss: 0.0098 - val_loss: 0.0095
# Epoch 91/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 92/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 93/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 94/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 95/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 96/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 97/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 98/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 99/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# Epoch 100/100
#  - 24s - loss: 0.0098 - val_loss: 0.0095
# step biases c1: -0.000, m1: -0.737, c2: 0.000, m2: -0.731
# rmse1: 0.180, rmse2: 0.177, (rmse1 + rmse2)/2: 0.179

# %%
model_spec = {'arch_name': 'cnn_image',
              'kwargs_arch': {'dropout_dense_rate': 0.3, 'out_dim': 2, 'use_discriminator': False, 'use_dropout_dense': True},
              'kwargs_dataset': {'noise_kernel_factor': 0.500,
                                 'noise_kernel_name': 'clash',
                                 'sim_names_test': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'sim_names_train': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
                                 'target_header_path': None},
              'kwargs_train': {'epochs': 100, 'label_loss': 'mean_squared_error', 'patience': 10},
              'trained_name': 'cnn_image_clash_uniform_mse_noise_0.500'}

post_sim_path = config['calibration_path'] + '/cosmos_to_clash_post_sim.npy'
model_spec['kwargs_dataset']['post_sim'] = np.load(expanduser(post_sim_path)).item()
model_spec['kwargs_dataset']['post_sim']['flux_factor'] = 0.32

train_a_spec(model_spec, do_train=True, save_calib=True, show_figures=True)
# Out:
# {'arch_name': 'cnn_image',
#  'kwargs_arch': {'dropout_dense_rate': 0.3, 'out_dim': 2, 'use_discriminator': False, 'use_dropout_dense': True},
#  'kwargs_dataset': {'noise_kernel_factor': 0.5,
#                     'noise_kernel_name': 'clash',
#                     'post_sim': {'flux_cut_min': -inf, 'flux_factor': 0.32, 'intensity_cutoff': 0.012},
#                     'sim_names_test': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
#                     'sim_names_train': ['low_002', 'med_002', 'hig_002', 'low_004', 'med_004', 'hig_004'],
#                     'target_header_path': None},
#  'kwargs_train': {'epochs': 100, 'label_loss': 'mean_squared_error', 'patience': 10},
#  'trained_name': 'cnn_image_clash_uniform_mse_noise_0.500'}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 10, 10, 64)        1664
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 10, 10, 40)        2600
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 10, 10, 10)        410
# _________________________________________________________________
# flatten (Flatten)            (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               100100
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                3030
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30)                0
# _________________________________________________________________
# label_pred (Dense)           (None, 2)                 62
# =================================================================
# Total params: 107,866
# Trainable params: 107,866
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  - 24s - loss: 0.0109 - val_loss: 0.0101
# Epoch 2/100
#  - 23s - loss: 0.0105 - val_loss: 0.0100
# Epoch 3/100
#  - 22s - loss: 0.0104 - val_loss: 0.0099
# Epoch 4/100
#  - 22s - loss: 0.0103 - val_loss: 0.0098
# Epoch 5/100
#  - 23s - loss: 0.0103 - val_loss: 0.0099
# Epoch 6/100
#  - 23s - loss: 0.0102 - val_loss: 0.0099
# Epoch 7/100
#  - 23s - loss: 0.0102 - val_loss: 0.0100
# Epoch 8/100
#  - 23s - loss: 0.0102 - val_loss: 0.0098
# Epoch 9/100
#  - 23s - loss: 0.0102 - val_loss: 0.0098
# Epoch 10/100
#  - 22s - loss: 0.0102 - val_loss: 0.0098
# Epoch 11/100
#  - 22s - loss: 0.0101 - val_loss: 0.0098
# Epoch 12/100
#  - 23s - loss: 0.0101 - val_loss: 0.0097
# Epoch 13/100
#  - 23s - loss: 0.0101 - val_loss: 0.0098
# Epoch 14/100
#  - 23s - loss: 0.0101 - val_loss: 0.0098
# Epoch 15/100
#
# Epoch 00015: reducing learning rate to 9.486833431105525e-05.
#  - 23s - loss: 0.0101 - val_loss: 0.0098
# Epoch 16/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 17/100
#  - 22s - loss: 0.0100 - val_loss: 0.0097
# Epoch 18/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 19/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 20/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 21/100
#  - 23s - loss: 0.0100 - val_loss: 0.0097
# Epoch 22/100
#  - 22s - loss: 0.0100 - val_loss: 0.0097
# Epoch 23/100
#  - 22s - loss: 0.0100 - val_loss: 0.0096
# Epoch 24/100
#  - 22s - loss: 0.0100 - val_loss: 0.0097
# Epoch 25/100
#  - 22s - loss: 0.0100 - val_loss: 0.0096
# Epoch 26/100
#  - 22s - loss: 0.0100 - val_loss: 0.0097
# Epoch 27/100
#
# Epoch 00027: reducing learning rate to 3.0000002378990563e-05.
#  - 23s - loss: 0.0100 - val_loss: 0.0096
# Epoch 28/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 29/100
#  - 23s - loss: 0.0100 - val_loss: 0.0096
# Epoch 30/100
#  - 22s - loss: 0.0100 - val_loss: 0.0096
# Epoch 31/100
#  - 23s - loss: 0.0100 - val_loss: 0.0096
# Epoch 32/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 33/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 34/100
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 35/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 36/100
#  - 24s - loss: 0.0100 - val_loss: 0.0096
# Epoch 37/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 38/100
#  - 23s - loss: 0.0100 - val_loss: 0.0096
# Epoch 39/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 40/100
#
# Epoch 00040: reducing learning rate to 9.48683389127749e-06.
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 41/100
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 42/100
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 43/100
#  - 26s - loss: 0.0100 - val_loss: 0.0096
# Epoch 44/100
#  - 27s - loss: 0.0099 - val_loss: 0.0096
# Epoch 45/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 46/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 47/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 48/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 49/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 50/100
#
# Epoch 00050: reducing learning rate to 3.0000002378990564e-06.
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 51/100
#  - 25s - loss: 0.0100 - val_loss: 0.0096
# Epoch 52/100
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 53/100
#  - 27s - loss: 0.0099 - val_loss: 0.0096
# Epoch 54/100
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 55/100
#  - 26s - loss: 0.0099 - val_loss: 0.0096
# Epoch 56/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 57/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 58/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 59/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 60/100
#
# Epoch 00060: reducing learning rate to 2e-06.
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 61/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 62/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 63/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 64/100
#  - 25s - loss: 0.0100 - val_loss: 0.0096
# Epoch 65/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 66/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 67/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 68/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 69/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 70/100
#  - 22s - loss: 0.0100 - val_loss: 0.0096
# Epoch 71/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 72/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 73/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 74/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 75/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 76/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 77/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 78/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 79/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 80/100
#  - 22s - loss: 0.0100 - val_loss: 0.0096
# Epoch 81/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 82/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 83/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 84/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 85/100
#  - 25s - loss: 0.0099 - val_loss: 0.0096
# Epoch 86/100
#  - 25s - loss: 0.0100 - val_loss: 0.0096
# Epoch 87/100
#  - 24s - loss: 0.0099 - val_loss: 0.0096
# Epoch 88/100
#  - 23s - loss: 0.0099 - val_loss: 0.0096
# Epoch 89/100
#  - 22s - loss: 0.0099 - val_loss: 0.0096
# Epoch 90/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 91/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 92/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 93/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 94/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 95/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 96/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 97/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 98/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 99/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# Epoch 100/100
#  - 21s - loss: 0.0099 - val_loss: 0.0096
# step biases c1: -0.000, m1: -0.744, c2: 0.000, m2: -0.741
# rmse1: 0.184, rmse2: 0.182, (rmse1 + rmse2)/2: 0.183
